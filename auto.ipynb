# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
result={}
driver = webdriver.Chrome(r"C:\Users\Vadim\Desktop\chromedriver.exe")
names=[["Соколов","Соколов1","Sokolov","“№:-)$&!$&№!_/__", "   ", "Соколов-Микитов", "С", "Соколов-Микитов-Ершов", "СоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколов", "СоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколовСоколов"],
       ["Вадим","Вадим1","Vadim","“№:-)$&!$&№!_/__", "   ", "Вадим-Михаил", "В", "Вадим-Михаил-Джим", "ВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадим", "ВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадимВадим" ],
       ["Михайлович", "Михайлович1", "Mikhaylovich", "“№:-)$&!$&№!_/__", "   ", "Михайлович-Витальевич", "М", "Михайлович-Витальевич-Петрович", "МихайловичМихайловичМихайловичМихайловичМихайловичМихайловичМихайловичМихайлович", "МихайловичМихайловичМихайловичМихайловичМихайловичМихайловичМихайловичМихайловичМихайловичМихайловичМихайлович"],
       ["Vadim", "Vadim1", "Вадим", "“№:-)$&!$&№!_/__", "   ", "Vadim-Mihail", "V", "Vadim-Mihail-Jim", "VadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadim", "VadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadimVadim"],
       ["Sokolov", "Sokolov1", "Соколов", "“№:-)$&!$&№!_/__", "   ", "Sokolov-Mikitov", "S", "Sokolov-Mikitov-Ershov", "SokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolov", "SokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolovSokolov"],
       ["№:-)$&!$&№!_/__", "1","1234567890"],
       ["    ", "почта@маил.ру", "example-@", "example@mail.ru", "examplemail.ru", "@mail.ru", "v@mail.ru", "super1user100999@mail.ru", "@mail.ru", "@mail.ru" ]]
driver.get("http://reg.congress.ru/users/registration/")
tests = ["-----Тестовые случаи к полю Фамилия:", "-----Тестовые случаи к полю Имя:", "-----Тестовые случаи к полю Отчество:", "-----Тестовые случаи к полю First name:", "-----Тестовые случаи к полю Last name:", "-----Тестовые случаи к полю Мобильный телефон:", "-----Тестовые случаи к полю Адрес электронной почты:", "Тестовый случай к полю Пол:", "Тестовый случай к полю Город проживания" ]
lastNameRu = driver.find_element_by_id("last-name-ru")
firstNameRu = driver.find_element_by_id("first-name-ru")
patronNameRu = driver.find_element_by_id("patron-name-ru")
firstNameEng = driver.find_element_by_id("first-name-eng")
lastNameEng = driver.find_element_by_id("last-name-eng")
mobile = driver.find_element_by_id("mobile")
email = driver.find_element_by_id("email")
sex = driver.find_element_by_id("sex")
city = driver.find_element_by_css_selector("div.entry-form > div ~ div > label ~ label > select")
field=[lastNameRu,
         firstNameRu,
         patronNameRu,
         firstNameEng,
         lastNameEng,
         mobile,
         email,
         sex,
         city]
field_true = [ "Соколов", "Вадим", "Михайлович", "Vadim", "Sokolov", "9999999999", "example@gmail.com"]
for i in range (0,7):
    field[i].send_keys(field_true[i])
field[7].send_keys(Keys.DOWN)
field[8].send_keys(Keys.DOWN)
for q in range (0,7):
    for i in range(0,len(names[q])):
        field[q].clear()
        field[q].send_keys(names[q][i])
        field[q].send_keys(Keys.ENTER)
        if ('Необходимо заполнить это поле.' in driver.find_element_by_tag_name("body").text):  
            result[names[q][i]] = 'Необходимо заполнить это поле.'
        elif ('Пожалуйста проверьте это поле.' in driver.find_element_by_tag_name("body").text):
            result[names[q][i]] = 'Пожалуйста проверьте это поле.'
        elif ('Длина поля должна быть не больше 100 символов.' in driver.find_element_by_tag_name("body").text):
            result[names[q][i]] = 'Длина поля должна быть не больше 100 символов.'
        elif ('Длина поля должна быть не больше 320 символов.' in driver.find_element_by_tag_name("body").text):
            result[names[q][i]] = 'Длина поля должна быть не больше 320 символов.'
        elif ('Введите в поле правильный адрес email' in driver.find_element_by_tag_name("body").text):
            result[names[q][i]] = 'Введите в поле правильный адрес email'
        else:
            result[names[q][i]] = 'OK'
        field[q].clear()
        field[q].send_keys(field_true[q])
    print(tests[q])
    for x in result:
        if (len(x) > 30):
            print(x[0:30],'\u2026',"=>",result[x])
        else:
            print(x, "=>", result[x])
    result.clear()
        
print(tests[7])
field[7].send_keys(Keys.UP)
if ('Необходимо заполнить это поле.' in driver.find_element_by_tag_name("body").text):  
    print('Оставить поле незаполненным =>  Необходимо заполнить это поле.')
else: 
    print('Оставить поле незаполненным =>  OK')
field[7].send_keys(Keys.DOWN)
print(tests[8])
field[8].send_keys(Keys.UP)
if ('Необходимо заполнить это поле.' in driver.find_element_by_tag_name("body").text):  
    print('Оставить поле незаполненным =>  Необходимо заполнить это поле.')
else:
    print('Оставить поле незаполненным =>  OK')
field[8].send_keys(Keys.DOWN)
# Out:
# -----Тестовые случаи к полю Фамилия:
# Соколов => OK
# Соколов1 => Пожалуйста проверьте это поле.
# Sokolov => Пожалуйста проверьте это поле.
# “№:-)$&!$&№!_/__ => Пожалуйста проверьте это поле.
#     => Необходимо заполнить это поле.
# Соколов-Микитов => OK
# С => OK
# Соколов-Микитов-Ершов => OK
# СоколовСоколовСоколовСоколовСо … => OK
# СоколовСоколовСоколовСоколовСо … => Длина поля должна быть не больше 100 символов.
# -----Тестовые случаи к полю Имя:
# Вадим => OK
# Вадим1 => Пожалуйста проверьте это поле.
# Vadim => Пожалуйста проверьте это поле.
# “№:-)$&!$&№!_/__ => Пожалуйста проверьте это поле.
#     => Необходимо заполнить это поле.
# Вадим-Михаил => OK
# В => OK
# Вадим-Михаил-Джим => OK
# ВадимВадимВадимВадимВадимВадим … => OK
# ВадимВадимВадимВадимВадимВадим … => Длина поля должна быть не больше 100 символов.
# -----Тестовые случаи к полю Отчество:
# Михайлович => OK
# Михайлович1 => Пожалуйста проверьте это поле.
# Mikhaylovich => Пожалуйста проверьте это поле.
# ...
